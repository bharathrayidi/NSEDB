# %%
# %run index_fn_data.py

# %%
# %run nifty_RL_predtion.py
# Out:
# 🚀 Starting Market Prediction Engine...
#
# 🔄 Checking for missing historical predictions...
#    > Found gap starting from 2025-12-10
#    > Training model for backfill/catch-up...
#    🧠 Training LSTM on 188 samples...
# WARNING:tensorflow:From c:\Users\2199222\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#    > Backfilled: 2025-12-10 | Pred: 25994.82 | Actual: 25758.00
#    > Backfilled: 2025-12-11 | Pred: 25993.02 | Actual: 25898.55
# ✅ Backfill complete. Added 2 entries.
#
# 🕵️ Validating 'nifty_predictions' table...
#    📝 Updating 3 rows in nifty_predictions...
#
# 🕵️ Validating 'nifty_daily_forecast' table...
#    📝 Updating 3 rows in nifty_daily_forecast...
#    ✅ Successfully validated 3 daily forecasts.
#
# 🔮 Generating Future Forecast...
#    🧠 Training LSTM on 190 samples...
#    > Raw LSTM Target: 26070.28
# ...

# %%
# %run stock_cash_data.py

# %%
# %run stock_fn_data.py
# Out:
# ✅ Table 'cash_market_full' ready in market_data.db.
# 🚀 FETCHING MASTER STOCK LIST (F&O)...
# ✅ Found 208 Stocks.
# ⏳ Starting Batch Ingestion...
# [208/208] Checking ZYDUSLIFE....
#
# 🎉 ALL CASH MARKET DATA SYNCED!

# %%
# %run stock_equal_list_data.py
# Out:
# ✅ Table 'equal_market_full' ready in market_data.db.
# 🚀 FETCHING MASTER STOCK LIST (F&O)...
# ✅ Found 2219 Stocks.
# ⏳ Starting Batch Ingestion...
# [2219/2219] Checking ZYDUSWELL....
#
# 🎉 ALL CASH MARKET DATA SYNCED!

# %%
# %run stocks_to_trader.py
# Out:
# 🚀 STARTING MARKET SCANNER...
# 📋 Scanning 208 stocks for setups...
#    found: CUMMINSIND -> SELL (Shooting Star)
#    found: CYIENT -> BUY (Hammer Rejection)
#    found: DABUR -> BUY (Hammer Rejection)
#    found: DMART -> BUY (Hammer Rejection)
#    found: EICHERMOT -> SELL (Shooting Star)
#    found: GMRAIRPORT -> BUY (Hammer Rejection)
#    found: HINDALCO -> SELL (Shooting Star)
#    found: HUDCO -> BUY (Hammer Rejection)
#    found: ICICIGI -> BUY (Hammer Rejection)
#    found: IDFCFIRSTB -> SELL (Shooting Star)
#    found: ITC -> BUY (Hammer Rejection)
#    found: LAURUSLABS -> SELL (Shooting Star)
#    found: NAUKRI -> BUY (Hammer Rejection)
#    found: NCC -> BUY (Hammer Rejection)
#    found: NHPC -> BUY (Hammer Rejection)
#    found: PETRONET -> BUY (Hammer Rejection)
#    found: PNB -> BUY (Hammer Rejection)
#    found: POWERGRID -> BUY (Hammer Rejection)
#    found: TITAN -> BUY (Hammer Rejection)
#    found: TRENT -> BUY (Hammer Rejection)
#
# ...

# %%
!-m streamlit run app.py

# %%
"C:\Users\2199222\AppData\Local\Programs\Python\Python312\python.exe" -m streamlit run app.py
