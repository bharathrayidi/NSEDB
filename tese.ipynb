# %%
# pip install dbt-sqlite

# %%
from nselib import derivatives
from displya import interactive_dataframe_display
interactive_dataframe_display(derivatives.future_price_volume_data(symbol="NIFTY", instrument='FUTIDX', period='1W'))
# Out:
#     <div style="padding: 10px; border: 2px solid #4287f5; border-radius: 5px; margin-bottom: 20px; background-color: #121212; color: white;">
#         <h2 style="color: #4287f5;">DataFrame Analysis</h2>
#         <p>This dataset contains <span id="table_5ae425a3_row_count">18</span> rows (showing <span id="table_5ae425a3_visible_count">18</span>).</p>
#
#         <div style="margin: 10px 0; display: flex; gap: 10px;">
#             <button id="table_5ae425a3_reset_filters" style="padding: 5px 10px; background-color: #f44336; color: white; border: none; border-radius: 3px; cursor: pointer;">Reset All Filters</button>
#             <button id="table_5ae425a3_download_csv" style="padding: 5px 10px; background-color: #4CAF50; color: white; border: none; border-radius: 3px; cursor: pointer;">Download as CSV</button>
#         </div>
#
#         <div style="overflow-x: auto; max-height: 500px; overflow-y: auto;">
# ...

# %%
# pip install bseindia

# %%
import bseindia
data = bseindia.equity_bhav_copy(trade_date='03-12-2025')

# %%
interactive_dataframe_display(data)
# Out:
#     <div style="padding: 10px; border: 2px solid #4287f5; border-radius: 5px; margin-bottom: 20px; background-color: #121212; color: white;">
#         <h2 style="color: #4287f5;">DataFrame Analysis</h2>
#         <p>This dataset contains <span id="table_b5637e2f_row_count">4738</span> rows (showing <span id="table_b5637e2f_visible_count">4738</span>).</p>
#
#         <div style="margin: 10px 0; display: flex; gap: 10px;">
#             <button id="table_b5637e2f_reset_filters" style="padding: 5px 10px; background-color: #f44336; color: white; border: none; border-radius: 3px; cursor: pointer;">Reset All Filters</button>
#             <button id="table_b5637e2f_download_csv" style="padding: 5px 10px; background-color: #4CAF50; color: white; border: none; border-radius: 3px; cursor: pointer;">Download as CSV</button>
#         </div>
#
#         <div style="overflow-x: auto; max-height: 500px; overflow-y: auto;">
# ...
